# %%
import numpy as np
import matplotlib.pyplot as plt
from corner_cutting import chaikins_corner_cutting

# %%
coords = np.array([
    [1, 2, 3, 4],
    [2, 2, 1, 1]
])
plt.plot(coords[0], coords[1])

# %%
coords2 = chaikins_corner_cutting(coords.T, 4).T
print(coords2.shape)
plt.plot(coords2[0], coords2[1])
# Out:
# (2, 64)

# %%
coords = np.array([
        [180, 59, 0],
        [150, 59, 50],
        [120, 55.5, 50],
        [100, 55.5, 20],
        [ 90, 55.5, 10],
])
#coords[:,0].T
plt.plot(coords[:,0], coords[:,1])

# %%
coords2 = chaikins_corner_cutting(coords, 1)
print(coords2.shape)
print(coords2)
plt.plot(coords2[:,0], coords2[:,1])
# Out:
# (10, 3)
# [[180.     59.      0.   ]
#  [172.5    59.     12.5  ]
#  [157.5    59.     37.5  ]
#  [142.5    58.125  50.   ]
#  [127.5    56.375  50.   ]
#  [115.     55.5    42.5  ]
#  [105.     55.5    27.5  ]
#  [ 97.5    55.5    17.5  ]
#  [ 92.5    55.5    12.5  ]
#  [ 90.     55.5    10.   ]]
